# %%
from OpenMSTools.ms_tools.align_tools import RTAlignerConfig

# %%
RTAlignerConfig().param_info
# Out:
#                                                 value default_value  \
# param_name
# max_num_peaks_considered                         1000          1000
# superimposer:mz_pair_max_distance                 0.5           0.5
# superimposer:rt_pair_distance_fraction            0.1           0.1
# superimposer:num_used_points                     2000          2000
# superimposer:scaling_bucket_size                0.005         0.005
# superimposer:shift_bucket_size                    3.0           3.0
# superimposer:max_shift                         1000.0        1000.0
# superimposer:max_scaling                          2.0           2.0
# superimposer:dump_buckets
# superimposer:dump_pairs
# pairfinder:second_nearest_gap                     2.0           2.0
# pairfinder:use_identifications                  false         false
# pairfinder:ignore_charge                        false         false
# pairfinder:ignore_adduct                         true          true
# ...

# %%
RTAlignerConfig().param
