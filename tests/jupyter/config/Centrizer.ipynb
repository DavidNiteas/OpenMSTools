# %%
from OpenMSTools.ms_tools.centroiding_tools import CentrizerConfig

# %%
CentrizerConfig().param_info
# Out:
#                                                         value  \
# param_name
# signal_to_noise                                           0.0
# spacing_difference_gap                                    4.0
# spacing_difference                                        1.5
# missing                                                     1
# ms_levels                                              [1, 2]
# report_FWHM                                             false
# report_FWHM_unit                                     relative
# SignalToNoise:max_intensity                                -1
# SignalToNoise:auto_max_stdev_factor                       3.0
# SignalToNoise:auto_max_percentile                          95
# SignalToNoise:auto_mode                                     0
# SignalToNoise:win_len                                   200.0
# SignalToNoise:bin_count                                    30
# SignalToNoise:min_required_elements                        10
# ...
