# %%
from OpenMSTools.ms_tools.adduct_tools import AdductDetectorConfig

# %%
AdductDetectorConfig().param_info
# Out:
#                                                                       value  \
# param_name
# charge_min                                                                1
# charge_max                                                                3
# charge_span_max                                                           3
# q_try                                                               feature
# retention_max_diff                                                      1.0
# retention_max_diff_local                                                1.0
# mass_max_diff                                                          0.05
# unit                                                                     Da
# max_neutrals                                                              1
# use_minority_bound                                                     true
# max_minority_bound                                                        3
# ...
